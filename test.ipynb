# %%
# import pandas as pd

# # df = pd.read_csv("/Volumes/HNSD02/outdir/ecd_wgs_features/9-ZMC014NB_S95025-S97025.sorted.final_output.tsv", sep = "\t", header = None)
# # df = pd.read_csv("/Volumes/HNSD02/outdir/ecd_wgs_features/input_test.final_output.tsv", sep = "\t", header = None)

# df1 = pd.read_csv("/Volumes/HNSD02/outdir/ecd_wgs_features/9-ZMC014NB_S95025-S97025.sorted.forward_Nucleosome.dist.bed", sep = "\t", header = None) 
# df2 = pd.read_csv("/Volumes/HNSD02/outdir/ecd_wgs_features/9-ZMC014NB_S95025-S97025.sorted.reverse_Nucleosome.dist.bed", sep = "\t", header = None) 
# df = pd.concat([df1, df2], axis = 0)

# nucdf = pd.DataFrame(data = df[12].values, columns = ["dist"])
# nucdf = nucdf[(nucdf["dist"] >= -300) & (nucdf["dist"] <= 300)]

# nucdf = nucdf.reset_index().groupby("dist").count().reset_index()
# nucdf["index"] = nucdf["index"].apply(lambda x: x/nucdf["index"].sum())

# nucdf.plot(x = "dist", y = "index")

import pandas as pd
df = pd.read_csv("/Volumes/HNSD02/outdir/ecd_wgs_features/9-ZMC014NB_S95025-S97025.sorted.final_output.tsv", sep = "\t", header = None)

# %%
nucdf1 = pd.DataFrame(data = df[9].values, columns = ["dist"]).reset_index()
nucdf2 = pd.DataFrame(data = df[10].values, columns = ["dist"]).reset_index()
nucdf = pd.concat([nucdf1, nucdf2], axis= 0)
nucdf = nucdf[(nucdf["dist"] >= -300) & (nucdf["dist"] <= 300)]
nucdf.groupby("dist").count().reset_index().plot(x = "dist", y = "index")
# Out:
# <Axes: xlabel='dist'>

# %%
maindf = pd.read_csv("/Users/hieunguyen/Downloads/MRD_GW_UMI_Phuc_HG19_release_20240606/9-ZMC014NB_S95025-S97025_features/9-ZMC014NB_S95025-S97025_GWfeature_Nucleosome.csv").set_index("Sample").T.reset_index()

# %%
maindf.plot(x = "index", y = "9-ZMC014NB_S95025-S97025" )
# Out:
# <Axes: xlabel='index'>

# %%
.
